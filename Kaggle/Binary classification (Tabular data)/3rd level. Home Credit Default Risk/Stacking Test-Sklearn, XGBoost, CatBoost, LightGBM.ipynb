# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
import xgboost as xgb
# from sklearn.cross_validation import KFold
from sklearn.model_selection import KFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from math import sqrt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import gc

import warnings 
warnings.filterwarnings('ignore')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# C:\ProgramData\Anaconda3\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# C:\ProgramData\Anaconda3\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)

# %%
NFOLDS = 3
SEED = 0
NROWS = None

# %%
data = pd.read_csv('application_train.csv')
test = pd.read_csv('application_test.csv')
prev = pd.read_csv('previous_application.csv')

# %%
categorical_feats = [f for f in data.columns if data[f].dtype == 'object']

for f_ in categorical_feats:
    data[f_], indexer = pd.factorize(data[f_])  # pd.factorize() 는 2가지 값을 반환. 첫번째 값은 정수로 인코딩된 값, 두번째 값은 인코딩된 범주
    test[f_] = indexer.get_indexer(test[f_])  # 반환된 인덱서로 test 데이터에 동일한 기준으로 적용하여 값만 반환
    
gc.enable()

y_train = data['TARGET']
del data['TARGET']

# %%
prev_cat_features = [f_ for f_ in prev.columns if prev[f_].dtype == 'object']
for f_ in prev_cat_features:
    prev[f_], _ = pd.factorize(prev[f_])  # _는 값을 무시하고 싶은 경우 사용
    
avg_prev = prev.groupby('SK_ID_CURR').mean()
cnt_prev = prev[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()  # 그룹별 SK_ID_PREV의 count
avg_prev['nb_app'] = cnt_prev['SK_ID_PREV']
del avg_prev['SK_ID_PREV']

# %%
x_train = data.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')
x_test = test.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')

x_train = x_train.fillna(0)
x_test= x_test.fillna(0)

ntrain = x_train.shape[0]
ntest = x_test.shape[0]

excluded_feats = ['SK_ID_CURR']
features = [f_ for f_ in x_train.columns if f_ not in excluded_feats]

x_train = x_train[features]
x_test = x_test[features]

kf = KFold(n_splits = NFOLDS, shuffle=True, random_state=SEED)

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]

class CatboostWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]
        
class LightGBMWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['feature_fraction_seed'] = seed
        params['bagging_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]


class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        self.nrounds = params.pop('nrounds', 250)

    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)

    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))

# %%
def get_oof(clf):
    oof_train = np.zeros((ntrain,))  # X_train 행 개수 만큼 numpy 배열 생성
    oof_test = np.zeros((ntest,))  # X_test 행 개수 만큼 numpy 배열 생성
    oof_test_skf = np.empty((NFOLDS, ntest))  # 인덱스 번호와 컬렉션의 원소를 tuple 형태로 반환

    for i, (train_index, test_index) in enumerate(kf.split(x_train)):
        x_tr = x_train.loc[train_index]
        y_tr = y_train.loc[train_index]
        x_te = x_train.loc[test_index]

        clf.train(x_tr, y_tr)

        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)

    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
et_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.5,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

rf_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.2,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

xgb_params = {
    'seed': 0,
    'colsample_bytree': 0.7,
    'silent': 1,
    'subsample': 0.7,
    'learning_rate': 0.075,
    'objective': 'binary:logistic',
    'max_depth': 4,
    'num_parallel_tree': 1,
    'min_child_weight': 1,
    'nrounds': 200
}

catboost_params = {
    'iterations': 200,
    'learning_rate': 0.5,
    'depth': 3,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter',
    'allow_writing_files': False
}

lightgbm_params = {
    'n_estimators':200,
    'learning_rate':0.1,
    'num_leaves':123,
    'colsample_bytree':0.8,
    'subsample':0.9,
    'max_depth':15,
    'reg_alpha':0.1,
    'reg_lambda':0.1,
    'min_split_gain':0.01,
    'min_child_weight':2    
}

# %%
xg = XgbWrapper(seed=SEED, params=xgb_params)
et = SklearnWrapper(clf=ExtraTreesClassifier, seed=SEED, params=et_params)
rf = SklearnWrapper(clf=RandomForestClassifier, seed=SEED, params=rf_params)
cb = CatboostWrapper(clf= CatBoostClassifier, seed = SEED, params=catboost_params)
lg = LightGBMWrapper(clf = LGBMClassifier, seed = SEED, params = lightgbm_params)

# %%
xg_oof_train, xg_oof_test = get_oof(xg)
et_oof_train, et_oof_test = get_oof(et)
rf_oof_train, rf_oof_test = get_oof(rf)
cb_oof_train, cb_oof_test = get_oof(cb)
# Out:
# [22:18:08] WARNING: C:\Users\dev-admin\croot2\xgboost-split_1675461376218\work\src\learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [22:19:02] WARNING: C:\Users\dev-admin\croot2\xgboost-split_1675461376218\work\src\learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [22:20:16] WARNING: C:\Users\dev-admin\croot2\xgboost-split_1675461376218\work\src\learner.cc:767:
# Parameters: { "silent" } are not used.
#
# 0:	total: 225ms	remaining: 44.8s
# 1:	total: 280ms	remaining: 27.7s
# 2:	total: 329ms	remaining: 21.6s
# 3:	total: 385ms	remaining: 18.8s
# 4:	total: 440ms	remaining: 17.2s
# 5:	total: 490ms	remaining: 15.8s
# 6:	total: 537ms	remaining: 14.8s
# 7:	total: 579ms	remaining: 13.9s
# 8:	total: 627ms	remaining: 13.3s
# 9:	total: 678ms	remaining: 12.9s
# 10:	total: 728ms	remaining: 12.5s
# 11:	total: 787ms	remaining: 12.3s
# 12:	total: 851ms	remaining: 12.2s
# 13:	total: 920ms	remaining: 12.2s
# 14:	total: 987ms	remaining: 12.2s
# 15:	total: 1.04s	remaining: 12s
# 16:	total: 1.09s	remaining: 11.7s
# 17:	total: 1.15s	remaining: 11.6s
# 18:	total: 1.21s	remaining: 11.5s
# 19:	total: 1.26s	remaining: 11.3s
# 20:	total: 1.32s	remaining: 11.2s
# 21:	total: 1.38s	remaining: 11.2s
# 22:	total: 1.44s	remaining: 11.1s
# 23:	total: 1.5s	remaining: 11s
# 24:	total: 1.56s	remaining: 10.9s
# 25:	total: 1.62s	remaining: 10.8s
# 26:	total: 1.67s	remaining: 10.7s
# 27:	total: 1.72s	remaining: 10.6s
# 28:	total: 1.78s	remaining: 10.5s
# 29:	total: 1.83s	remaining: 10.4s
# 30:	total: 1.88s	remaining: 10.2s
# 31:	total: 1.93s	remaining: 10.2s
# 32:	total: 1.99s	remaining: 10.1s
# 33:	total: 2.04s	remaining: 9.96s
# 34:	total: 2.09s	remaining: 9.84s
# 35:	total: 2.13s	remaining: 9.72s
# 36:	total: 2.19s	remaining: 9.67s
# 37:	total: 2.26s	remaining: 9.65s
# 38:	total: 2.33s	remaining: 9.63s
# 39:	total: 2.41s	remaining: 9.63s
# 40:	total: 2.47s	remaining: 9.57s
# 41:	total: 2.52s	remaining: 9.48s
# 42:	total: 2.57s	remaining: 9.37s
# 43:	total: 2.62s	remaining: 9.3s
# 44:	total: 2.68s	remaining: 9.22s
# 45:	total: 2.73s	remaining: 9.15s
# 46:	total: 2.79s	remaining: 9.07s
# 47:	total: 2.83s	remaining: 8.97s
# 48:	total: 2.88s	remaining: 8.88s
# 49:	total: 2.94s	remaining: 8.82s
# 50:	total: 2.98s	remaining: 8.72s
# 51:	total: 3.03s	remaining: 8.64s
# 52:	total: 3.1s	remaining: 8.6s
# 53:	total: 3.15s	remaining: 8.52s
# 54:	total: 3.2s	remaining: 8.44s
# 55:	total: 3.26s	remaining: 8.38s
# 56:	total: 3.31s	remaining: 8.31s
# 57:	total: 3.38s	remaining: 8.27s
# 58:	total: 3.42s	remaining: 8.18s
# 59:	total: 3.49s	remaining: 8.14s
# 60:	total: 3.55s	remaining: 8.09s
# 61:	total: 3.6s	remaining: 8.02s
# 62:	total: 3.66s	remaining: 7.97s
# 63:	total: 3.72s	remaining: 7.91s
# 64:	total: 3.79s	remaining: 7.86s
# 65:	total: 3.85s	remaining: 7.81s
# 66:	total: 3.9s	remaining: 7.74s
# 67:	total: 3.98s	remaining: 7.72s
# 68:	total: 4.04s	remaining: 7.67s
# 69:	total: 4.1s	remaining: 7.62s
# 70:	total: 4.17s	remaining: 7.58s
# 71:	total: 4.23s	remaining: 7.52s
# 72:	total: 4.29s	remaining: 7.47s
# 73:	total: 4.35s	remaining: 7.4s
# 74:	total: 4.4s	remaining: 7.34s
# 75:	total: 4.46s	remaining: 7.28s
# 76:	total: 4.51s	remaining: 7.2s
# 77:	total: 4.56s	remaining: 7.13s
# 78:	total: 4.61s	remaining: 7.06s
# 79:	total: 4.68s	remaining: 7.02s
# 80:	total: 4.74s	remaining: 6.96s
# 81:	total: 4.8s	remaining: 6.91s
# 82:	total: 4.86s	remaining: 6.85s
# 83:	total: 4.92s	remaining: 6.8s
# 84:	total: 5s	remaining: 6.77s
# 85:	total: 5.07s	remaining: 6.72s
# 86:	total: 5.14s	remaining: 6.68s
# 87:	total: 5.21s	remaining: 6.63s
# 88:	total: 5.29s	remaining: 6.59s
# 89:	total: 5.36s	remaining: 6.54s
# 90:	total: 5.43s	remaining: 6.5s
# 91:	total: 5.49s	remaining: 6.45s
# 92:	total: 5.55s	remaining: 6.39s
# 93:	total: 5.61s	remaining: 6.33s
# 94:	total: 5.68s	remaining: 6.28s
# 95:	total: 5.75s	remaining: 6.23s
# 96:	total: 5.8s	remaining: 6.16s
# 97:	total: 5.88s	remaining: 6.12s
# 98:	total: 5.93s	remaining: 6.05s
# 99:	total: 6s	remaining: 6s
# 100:	total: 6.06s	remaining: 5.94s
# 101:	total: 6.12s	remaining: 5.88s
# 102:	total: 6.18s	remaining: 5.82s
# 103:	total: 6.24s	remaining: 5.75s
# 104:	total: 6.29s	remaining: 5.69s
# 105:	total: 6.34s	remaining: 5.62s
# 106:	total: 6.39s	remaining: 5.55s
# 107:	total: 6.45s	remaining: 5.49s
# 108:	total: 6.52s	remaining: 5.44s
# 109:	total: 6.57s	remaining: 5.38s
# 110:	total: 6.62s	remaining: 5.31s
# 111:	total: 6.68s	remaining: 5.25s
# 112:	total: 6.73s	remaining: 5.18s
# 113:	total: 6.79s	remaining: 5.12s
# 114:	total: 6.84s	remaining: 5.06s
# 115:	total: 6.89s	remaining: 4.99s
# 116:	total: 6.95s	remaining: 4.93s
# 117:	total: 7s	remaining: 4.87s
# 118:	total: 7.08s	remaining: 4.82s
# 119:	total: 7.14s	remaining: 4.76s
# 120:	total: 7.2s	remaining: 4.7s
# 121:	total: 7.26s	remaining: 4.64s
# 122:	total: 7.32s	remaining: 4.58s
# 123:	total: 7.39s	remaining: 4.53s
# 124:	total: 7.46s	remaining: 4.48s
# 125:	total: 7.54s	remaining: 4.43s
# 126:	total: 7.61s	remaining: 4.37s
# 127:	total: 7.66s	remaining: 4.31s
# 128:	total: 7.72s	remaining: 4.25s
# 129:	total: 7.78s	remaining: 4.19s
# 130:	total: 7.84s	remaining: 4.13s
# 131:	total: 7.89s	remaining: 4.07s
# 132:	total: 7.95s	remaining: 4.01s
# 133:	total: 8.01s	remaining: 3.95s
# 134:	total: 8.07s	remaining: 3.89s
# 135:	total: 8.14s	remaining: 3.83s
# 136:	total: 8.2s	remaining: 3.77s
# 137:	total: 8.27s	remaining: 3.71s
# 138:	total: 8.32s	remaining: 3.65s
# 139:	total: 8.38s	remaining: 3.59s
# 140:	total: 8.44s	remaining: 3.53s
# 141:	total: 8.49s	remaining: 3.47s
# 142:	total: 8.56s	remaining: 3.41s
# 143:	total: 8.62s	remaining: 3.35s
# 144:	total: 8.68s	remaining: 3.29s
# 145:	total: 8.74s	remaining: 3.23s
# 146:	total: 8.8s	remaining: 3.17s
# 147:	total: 8.86s	remaining: 3.11s
# 148:	total: 8.93s	remaining: 3.06s
# 149:	total: 8.99s	remaining: 3s
# 150:	total: 9.05s	remaining: 2.94s
# 151:	total: 9.11s	remaining: 2.88s
# 152:	total: 9.18s	remaining: 2.82s
# 153:	total: 9.25s	remaining: 2.76s
# 154:	total: 9.3s	remaining: 2.7s
# 155:	total: 9.36s	remaining: 2.64s
# 156:	total: 9.42s	remaining: 2.58s
# 157:	total: 9.48s	remaining: 2.52s
# 158:	total: 9.55s	remaining: 2.46s
# 159:	total: 9.61s	remaining: 2.4s
# 160:	total: 9.67s	remaining: 2.34s
# 161:	total: 9.74s	remaining: 2.29s
# 162:	total: 9.8s	remaining: 2.23s
# 163:	total: 9.86s	remaining: 2.16s
# 164:	total: 9.92s	remaining: 2.1s
# 165:	total: 9.98s	remaining: 2.04s
# 166:	total: 10s	remaining: 1.98s
# 167:	total: 10.1s	remaining: 1.92s
# 168:	total: 10.2s	remaining: 1.86s
# 169:	total: 10.2s	remaining: 1.8s
# 170:	total: 10.3s	remaining: 1.74s
# 171:	total: 10.3s	remaining: 1.68s
# 172:	total: 10.4s	remaining: 1.62s
# 173:	total: 10.5s	remaining: 1.56s
# 174:	total: 10.5s	remaining: 1.5s
# 175:	total: 10.6s	remaining: 1.44s
# 176:	total: 10.6s	remaining: 1.38s
# 177:	total: 10.7s	remaining: 1.32s
# 178:	total: 10.7s	remaining: 1.26s
# 179:	total: 10.8s	remaining: 1.2s
# 180:	total: 10.9s	remaining: 1.14s
# 181:	total: 10.9s	remaining: 1.08s
# 182:	total: 11s	remaining: 1.02s
# 183:	total: 11.1s	remaining: 961ms
# 184:	total: 11.1s	remaining: 903ms
# 185:	total: 11.2s	remaining: 844ms
# 186:	total: 11.3s	remaining: 784ms
# 187:	total: 11.4s	remaining: 725ms
# 188:	total: 11.4s	remaining: 665ms
# 189:	total: 11.5s	remaining: 605ms
# 190:	total: 11.6s	remaining: 545ms
# 191:	total: 11.6s	remaining: 484ms
# 192:	total: 11.7s	remaining: 424ms
# 193:	total: 11.7s	remaining: 363ms
# 194:	total: 11.8s	remaining: 303ms
# 195:	total: 11.8s	remaining: 242ms
# 196:	total: 11.9s	remaining: 181ms
# 197:	total: 12s	remaining: 121ms
# 198:	total: 12s	remaining: 60.4ms
# 199:	total: 12.1s	remaining: 0us
# 0:	total: 66ms	remaining: 13.1s
# 1:	total: 115ms	remaining: 11.4s
# 2:	total: 161ms	remaining: 10.6s
# 3:	total: 206ms	remaining: 10.1s
# 4:	total: 260ms	remaining: 10.2s
# 5:	total: 330ms	remaining: 10.7s
# 6:	total: 382ms	remaining: 10.5s
# 7:	total: 442ms	remaining: 10.6s
# 8:	total: 511ms	remaining: 10.8s
# 9:	total: 562ms	remaining: 10.7s
# 10:	total: 616ms	remaining: 10.6s
# 11:	total: 672ms	remaining: 10.5s
# 12:	total: 740ms	remaining: 10.6s
# 13:	total: 811ms	remaining: 10.8s
# 14:	total: 863ms	remaining: 10.6s
# 15:	total: 925ms	remaining: 10.6s
# 16:	total: 988ms	remaining: 10.6s
# 17:	total: 1.05s	remaining: 10.6s
# 18:	total: 1.1s	remaining: 10.5s
# 19:	total: 1.16s	remaining: 10.5s
# 20:	total: 1.22s	remaining: 10.4s
# 21:	total: 1.28s	remaining: 10.4s
# 22:	total: 1.36s	remaining: 10.4s
# 23:	total: 1.43s	remaining: 10.5s
# 24:	total: 1.49s	remaining: 10.4s
# 25:	total: 1.55s	remaining: 10.4s
# 26:	total: 1.61s	remaining: 10.3s
# 27:	total: 1.67s	remaining: 10.3s
# 28:	total: 1.73s	remaining: 10.2s
# 29:	total: 1.79s	remaining: 10.1s
# 30:	total: 1.84s	remaining: 10s
# 31:	total: 1.89s	remaining: 9.95s
# 32:	total: 1.94s	remaining: 9.83s
# 33:	total: 1.99s	remaining: 9.73s
# 34:	total: 2.04s	remaining: 9.61s
# 35:	total: 2.09s	remaining: 9.52s
# 36:	total: 2.14s	remaining: 9.45s
# 37:	total: 2.19s	remaining: 9.34s
# 38:	total: 2.24s	remaining: 9.26s
# 39:	total: 2.29s	remaining: 9.18s
# 40:	total: 2.36s	remaining: 9.16s
# 41:	total: 2.42s	remaining: 9.12s
# 42:	total: 2.49s	remaining: 9.09s
# 43:	total: 2.55s	remaining: 9.04s
# 44:	total: 2.6s	remaining: 8.95s
# 45:	total: 2.65s	remaining: 8.88s
# 46:	total: 2.7s	remaining: 8.79s
# 47:	total: 2.76s	remaining: 8.74s
# 48:	total: 2.82s	remaining: 8.7s
# 49:	total: 2.88s	remaining: 8.64s
# 50:	total: 2.94s	remaining: 8.59s
# 51:	total: 3s	remaining: 8.53s
# 52:	total: 3.07s	remaining: 8.52s
# 53:	total: 3.13s	remaining: 8.45s
# 54:	total: 3.18s	remaining: 8.39s
# 55:	total: 3.24s	remaining: 8.33s
# 56:	total: 3.3s	remaining: 8.27s
# 57:	total: 3.36s	remaining: 8.23s
# 58:	total: 3.42s	remaining: 8.19s
# 59:	total: 3.5s	remaining: 8.16s
# 60:	total: 3.56s	remaining: 8.1s
# 61:	total: 3.62s	remaining: 8.06s
# 62:	total: 3.69s	remaining: 8.01s
# 63:	total: 3.75s	remaining: 7.97s
# 64:	total: 3.83s	remaining: 7.95s
# 65:	total: 3.89s	remaining: 7.9s
# 66:	total: 3.95s	remaining: 7.84s
# 67:	total: 4.01s	remaining: 7.79s
# 68:	total: 4.08s	remaining: 7.74s
# 69:	total: 4.14s	remaining: 7.68s
# 70:	total: 4.2s	remaining: 7.62s
# 71:	total: 4.26s	remaining: 7.58s
# 72:	total: 4.33s	remaining: 7.53s
# 73:	total: 4.39s	remaining: 7.48s
# 74:	total: 4.46s	remaining: 7.43s
# 75:	total: 4.53s	remaining: 7.4s
# 76:	total: 4.61s	remaining: 7.36s
# 77:	total: 4.68s	remaining: 7.32s
# 78:	total: 4.74s	remaining: 7.26s
# 79:	total: 4.81s	remaining: 7.21s
# 80:	total: 4.87s	remaining: 7.16s
# 81:	total: 4.96s	remaining: 7.13s
# 82:	total: 5.09s	remaining: 7.17s
# 83:	total: 5.21s	remaining: 7.19s
# 84:	total: 5.29s	remaining: 7.16s
# 85:	total: 5.4s	remaining: 7.15s
# 86:	total: 5.49s	remaining: 7.13s
# 87:	total: 5.57s	remaining: 7.09s
# 88:	total: 5.67s	remaining: 7.07s
# 89:	total: 5.74s	remaining: 7.01s
# 90:	total: 5.82s	remaining: 6.97s
# 91:	total: 5.9s	remaining: 6.93s
# 92:	total: 5.96s	remaining: 6.86s
# 93:	total: 6.05s	remaining: 6.83s
# 94:	total: 6.14s	remaining: 6.79s
# 95:	total: 6.23s	remaining: 6.75s
# 96:	total: 6.29s	remaining: 6.68s
# 97:	total: 6.36s	remaining: 6.62s
# 98:	total: 6.42s	remaining: 6.55s
# 99:	total: 6.5s	remaining: 6.5s
# 100:	total: 6.57s	remaining: 6.44s
# 101:	total: 6.64s	remaining: 6.38s
# 102:	total: 6.71s	remaining: 6.32s
# 103:	total: 6.79s	remaining: 6.26s
# 104:	total: 6.85s	remaining: 6.2s
# 105:	total: 6.92s	remaining: 6.13s
# 106:	total: 7.01s	remaining: 6.09s
# 107:	total: 7.09s	remaining: 6.04s
# 108:	total: 7.17s	remaining: 5.98s
# 109:	total: 7.24s	remaining: 5.92s
# 110:	total: 7.31s	remaining: 5.86s
# 111:	total: 7.41s	remaining: 5.82s
# 112:	total: 7.48s	remaining: 5.76s
# 113:	total: 7.57s	remaining: 5.71s
# 114:	total: 7.63s	remaining: 5.64s
# 115:	total: 7.71s	remaining: 5.58s
# 116:	total: 7.78s	remaining: 5.52s
# 117:	total: 7.85s	remaining: 5.46s
# 118:	total: 7.92s	remaining: 5.39s
# 119:	total: 7.99s	remaining: 5.33s
# 120:	total: 8.05s	remaining: 5.25s
# 121:	total: 8.12s	remaining: 5.19s
# 122:	total: 8.19s	remaining: 5.13s
# 123:	total: 8.25s	remaining: 5.06s
# 124:	total: 8.34s	remaining: 5s
# 125:	total: 8.41s	remaining: 4.94s
# 126:	total: 8.49s	remaining: 4.88s
# 127:	total: 8.56s	remaining: 4.82s
# 128:	total: 8.62s	remaining: 4.74s
# 129:	total: 8.68s	remaining: 4.67s
# 130:	total: 8.75s	remaining: 4.61s
# 131:	total: 8.82s	remaining: 4.54s
# 132:	total: 8.88s	remaining: 4.47s
# 133:	total: 8.95s	remaining: 4.41s
# 134:	total: 9.02s	remaining: 4.34s
# 135:	total: 9.09s	remaining: 4.28s
# 136:	total: 9.19s	remaining: 4.23s
# 137:	total: 9.29s	remaining: 4.17s
# 138:	total: 9.37s	remaining: 4.11s
# 139:	total: 9.46s	remaining: 4.05s
# 140:	total: 9.54s	remaining: 3.99s
# 141:	total: 9.62s	remaining: 3.93s
# 142:	total: 9.7s	remaining: 3.87s
# 143:	total: 9.76s	remaining: 3.8s
# 144:	total: 9.83s	remaining: 3.73s
# 145:	total: 9.89s	remaining: 3.66s
# 146:	total: 9.95s	remaining: 3.59s
# 147:	total: 10s	remaining: 3.52s
# 148:	total: 10.1s	remaining: 3.45s
# 149:	total: 10.2s	remaining: 3.39s
# 150:	total: 10.2s	remaining: 3.32s
# 151:	total: 10.3s	remaining: 3.26s
# 152:	total: 10.4s	remaining: 3.2s
# 153:	total: 10.5s	remaining: 3.13s
# 154:	total: 10.6s	remaining: 3.07s
# 155:	total: 10.7s	remaining: 3.01s
# 156:	total: 10.7s	remaining: 2.94s
# 157:	total: 10.8s	remaining: 2.88s
# 158:	total: 10.9s	remaining: 2.81s
# 159:	total: 11s	remaining: 2.74s
# 160:	total: 11s	remaining: 2.68s
# 161:	total: 11.1s	remaining: 2.61s
# 162:	total: 11.2s	remaining: 2.54s
# 163:	total: 11.3s	remaining: 2.48s
# 164:	total: 11.4s	remaining: 2.42s
# 165:	total: 11.5s	remaining: 2.35s
# 166:	total: 11.6s	remaining: 2.29s
# 167:	total: 11.7s	remaining: 2.22s
# 168:	total: 11.7s	remaining: 2.15s
# 169:	total: 11.8s	remaining: 2.08s
# 170:	total: 11.9s	remaining: 2.01s
# 171:	total: 12s	remaining: 1.95s
# 172:	total: 12.1s	remaining: 1.89s
# 173:	total: 12.2s	remaining: 1.82s
# 174:	total: 12.3s	remaining: 1.75s
# 175:	total: 12.4s	remaining: 1.69s
# 176:	total: 12.4s	remaining: 1.62s
# 177:	total: 12.5s	remaining: 1.55s
# 178:	total: 12.6s	remaining: 1.48s
# 179:	total: 12.7s	remaining: 1.41s
# 180:	total: 12.8s	remaining: 1.34s
# 181:	total: 12.9s	remaining: 1.27s
# 182:	total: 12.9s	remaining: 1.2s
# 183:	total: 13s	remaining: 1.13s
# 184:	total: 13.1s	remaining: 1.06s
# 185:	total: 13.2s	remaining: 993ms
# 186:	total: 13.3s	remaining: 923ms
# 187:	total: 13.4s	remaining: 855ms
# 188:	total: 13.5s	remaining: 785ms
# 189:	total: 13.6s	remaining: 714ms
# 190:	total: 13.7s	remaining: 644ms
# 191:	total: 13.8s	remaining: 573ms
# 192:	total: 13.8s	remaining: 502ms
# 193:	total: 13.9s	remaining: 430ms
# 194:	total: 14s	remaining: 359ms
# 195:	total: 14.1s	remaining: 287ms
# 196:	total: 14.1s	remaining: 215ms
# 197:	total: 14.2s	remaining: 144ms
# 198:	total: 14.3s	remaining: 71.7ms
# 199:	total: 14.4s	remaining: 0us
# 0:	total: 72.3ms	remaining: 14.4s
# 1:	total: 132ms	remaining: 13s
# 2:	total: 211ms	remaining: 13.9s
# 3:	total: 276ms	remaining: 13.5s
# 4:	total: 350ms	remaining: 13.7s
# 5:	total: 423ms	remaining: 13.7s
# 6:	total: 490ms	remaining: 13.5s
# 7:	total: 557ms	remaining: 13.4s
# 8:	total: 652ms	remaining: 13.8s
# 9:	total: 737ms	remaining: 14s
# 10:	total: 827ms	remaining: 14.2s
# 11:	total: 914ms	remaining: 14.3s
# 12:	total: 994ms	remaining: 14.3s
# 13:	total: 1.08s	remaining: 14.4s
# 14:	total: 1.17s	remaining: 14.4s
# 15:	total: 1.23s	remaining: 14.2s
# 16:	total: 1.31s	remaining: 14.2s
# 17:	total: 1.38s	remaining: 13.9s
# 18:	total: 1.47s	remaining: 14s
# 19:	total: 1.54s	remaining: 13.9s
# 20:	total: 1.62s	remaining: 13.8s
# 21:	total: 1.71s	remaining: 13.8s
# 22:	total: 1.8s	remaining: 13.8s
# 23:	total: 1.89s	remaining: 13.8s
# 24:	total: 1.97s	remaining: 13.8s
# 25:	total: 2.05s	remaining: 13.7s
# 26:	total: 2.12s	remaining: 13.6s
# 27:	total: 2.2s	remaining: 13.5s
# 28:	total: 2.27s	remaining: 13.4s
# 29:	total: 2.35s	remaining: 13.3s
# 30:	total: 2.44s	remaining: 13.3s
# 31:	total: 2.52s	remaining: 13.2s
# 32:	total: 2.6s	remaining: 13.1s
# 33:	total: 2.69s	remaining: 13.2s
# 34:	total: 2.78s	remaining: 13.1s
# 35:	total: 2.86s	remaining: 13s
# 36:	total: 2.96s	remaining: 13s
# 37:	total: 3.03s	remaining: 12.9s
# 38:	total: 3.13s	remaining: 12.9s
# 39:	total: 3.21s	remaining: 12.8s
# 40:	total: 3.3s	remaining: 12.8s
# 41:	total: 3.39s	remaining: 12.7s
# 42:	total: 3.48s	remaining: 12.7s
# 43:	total: 3.57s	remaining: 12.7s
# 44:	total: 3.64s	remaining: 12.5s
# 45:	total: 3.71s	remaining: 12.4s
# 46:	total: 3.8s	remaining: 12.4s
# 47:	total: 3.9s	remaining: 12.3s
# 48:	total: 3.97s	remaining: 12.2s
# 49:	total: 4.05s	remaining: 12.2s
# 50:	total: 4.14s	remaining: 12.1s
# 51:	total: 4.21s	remaining: 12s
# 52:	total: 4.29s	remaining: 11.9s
# 53:	total: 4.36s	remaining: 11.8s
# 54:	total: 4.44s	remaining: 11.7s
# 55:	total: 4.52s	remaining: 11.6s
# 56:	total: 4.6s	remaining: 11.5s
# 57:	total: 4.68s	remaining: 11.5s
# 58:	total: 4.77s	remaining: 11.4s
# 59:	total: 4.85s	remaining: 11.3s
# 60:	total: 4.92s	remaining: 11.2s
# 61:	total: 5.01s	remaining: 11.1s
# 62:	total: 5.08s	remaining: 11s
# 63:	total: 5.16s	remaining: 11s
# 64:	total: 5.22s	remaining: 10.9s
# 65:	total: 5.3s	remaining: 10.8s
# 66:	total: 5.41s	remaining: 10.7s
# 67:	total: 5.49s	remaining: 10.7s
# 68:	total: 5.56s	remaining: 10.6s
# 69:	total: 5.63s	remaining: 10.5s
# 70:	total: 5.7s	remaining: 10.4s
# 71:	total: 5.76s	remaining: 10.2s
# 72:	total: 5.83s	remaining: 10.1s
# 73:	total: 5.91s	remaining: 10.1s
# 74:	total: 5.98s	remaining: 9.97s
# 75:	total: 6.06s	remaining: 9.88s
# 76:	total: 6.15s	remaining: 9.82s
# 77:	total: 6.21s	remaining: 9.72s
# 78:	total: 6.27s	remaining: 9.61s
# 79:	total: 6.33s	remaining: 9.49s
# 80:	total: 6.39s	remaining: 9.38s
# 81:	total: 6.45s	remaining: 9.28s
# 82:	total: 6.5s	remaining: 9.17s
# 83:	total: 6.56s	remaining: 9.06s
# 84:	total: 6.63s	remaining: 8.97s
# 85:	total: 6.71s	remaining: 8.9s
# 86:	total: 6.78s	remaining: 8.81s
# 87:	total: 6.86s	remaining: 8.72s
# 88:	total: 6.93s	remaining: 8.64s
# 89:	total: 7s	remaining: 8.56s
# 90:	total: 7.09s	remaining: 8.49s
# 91:	total: 7.19s	remaining: 8.44s
# 92:	total: 7.27s	remaining: 8.37s
# 93:	total: 7.35s	remaining: 8.29s
# 94:	total: 7.43s	remaining: 8.21s
# 95:	total: 7.5s	remaining: 8.13s
# 96:	total: 7.58s	remaining: 8.05s
# 97:	total: 7.65s	remaining: 7.96s
# 98:	total: 7.72s	remaining: 7.88s
# 99:	total: 7.79s	remaining: 7.79s
# 100:	total: 7.88s	remaining: 7.73s
# 101:	total: 7.95s	remaining: 7.64s
# 102:	total: 8.02s	remaining: 7.55s
# 103:	total: 8.09s	remaining: 7.47s
# 104:	total: 8.18s	remaining: 7.4s
# 105:	total: 8.26s	remaining: 7.33s
# 106:	total: 8.34s	remaining: 7.24s
# 107:	total: 8.42s	remaining: 7.18s
# 108:	total: 8.51s	remaining: 7.1s
# 109:	total: 8.59s	remaining: 7.03s
# 110:	total: 8.68s	remaining: 6.96s
# 111:	total: 8.75s	remaining: 6.87s
# 112:	total: 8.83s	remaining: 6.8s
# 113:	total: 8.9s	remaining: 6.72s
# 114:	total: 8.98s	remaining: 6.64s
# 115:	total: 9.07s	remaining: 6.57s
# 116:	total: 9.14s	remaining: 6.49s
# 117:	total: 9.24s	remaining: 6.42s
# 118:	total: 9.33s	remaining: 6.35s
# 119:	total: 9.4s	remaining: 6.27s
# 120:	total: 9.5s	remaining: 6.2s
# 121:	total: 9.57s	remaining: 6.12s
# 122:	total: 9.63s	remaining: 6.03s
# 123:	total: 9.69s	remaining: 5.94s
# 124:	total: 9.75s	remaining: 5.85s
# 125:	total: 9.8s	remaining: 5.76s
# 126:	total: 9.88s	remaining: 5.68s
# 127:	total: 9.94s	remaining: 5.59s
# 128:	total: 10s	remaining: 5.52s
# 129:	total: 10.1s	remaining: 5.44s
# 130:	total: 10.2s	remaining: 5.36s
# 131:	total: 10.2s	remaining: 5.28s
# 132:	total: 10.3s	remaining: 5.19s
# 133:	total: 10.4s	remaining: 5.13s
# 134:	total: 10.5s	remaining: 5.04s
# 135:	total: 10.6s	remaining: 4.97s
# 136:	total: 10.6s	remaining: 4.89s
# 137:	total: 10.7s	remaining: 4.81s
# 138:	total: 10.8s	remaining: 4.73s
# 139:	total: 10.8s	remaining: 4.65s
# 140:	total: 10.9s	remaining: 4.57s
# 141:	total: 11s	remaining: 4.5s
# 142:	total: 11.1s	remaining: 4.42s
# 143:	total: 11.2s	remaining: 4.34s
# 144:	total: 11.2s	remaining: 4.26s
# 145:	total: 11.3s	remaining: 4.18s
# 146:	total: 11.4s	remaining: 4.11s
# 147:	total: 11.5s	remaining: 4.03s
# 148:	total: 11.5s	remaining: 3.95s
# 149:	total: 11.6s	remaining: 3.88s
# 150:	total: 11.7s	remaining: 3.79s
# 151:	total: 11.7s	remaining: 3.71s
# 152:	total: 11.8s	remaining: 3.63s
# 153:	total: 11.9s	remaining: 3.55s
# 154:	total: 11.9s	remaining: 3.46s
# 155:	total: 12s	remaining: 3.38s
# 156:	total: 12s	remaining: 3.3s
# 157:	total: 12.1s	remaining: 3.21s
# 158:	total: 12.1s	remaining: 3.13s
# 159:	total: 12.2s	remaining: 3.05s
# 160:	total: 12.3s	remaining: 2.98s
# 161:	total: 12.3s	remaining: 2.9s
# 162:	total: 12.4s	remaining: 2.82s
# 163:	total: 12.5s	remaining: 2.75s
# 164:	total: 12.6s	remaining: 2.67s
# 165:	total: 12.6s	remaining: 2.59s
# 166:	total: 12.7s	remaining: 2.51s
# 167:	total: 12.8s	remaining: 2.43s
# 168:	total: 12.8s	remaining: 2.35s
# 169:	total: 12.9s	remaining: 2.28s
# 170:	total: 13s	remaining: 2.2s
# 171:	total: 13.1s	remaining: 2.13s
# 172:	total: 13.2s	remaining: 2.05s
# 173:	total: 13.2s	remaining: 1.97s
# 174:	total: 13.3s	remaining: 1.9s
# 175:	total: 13.4s	remaining: 1.83s
# 176:	total: 13.5s	remaining: 1.75s
# 177:	total: 13.6s	remaining: 1.68s
# 178:	total: 13.7s	remaining: 1.6s
# 179:	total: 13.8s	remaining: 1.53s
# 180:	total: 13.8s	remaining: 1.45s
# 181:	total: 13.9s	remaining: 1.38s
# 182:	total: 14s	remaining: 1.3s
# 183:	total: 14s	remaining: 1.22s
# 184:	total: 14.1s	remaining: 1.14s
# 185:	total: 14.2s	remaining: 1.07s
# 186:	total: 14.3s	remaining: 991ms
# 187:	total: 14.3s	remaining: 915ms
# 188:	total: 14.4s	remaining: 839ms
# 189:	total: 14.5s	remaining: 762ms
# 190:	total: 14.5s	remaining: 686ms
# 191:	total: 14.6s	remaining: 609ms
# 192:	total: 14.7s	remaining: 533ms
# 193:	total: 14.8s	remaining: 457ms
# 194:	total: 14.9s	remaining: 381ms
# 195:	total: 14.9s	remaining: 304ms
# 196:	total: 15s	remaining: 228ms
# 197:	total: 15s	remaining: 152ms
# 198:	total: 15.1s	remaining: 76ms
# 199:	total: 15.2s	remaining: 0us

# %%
print("XG-CV: {}".format(sqrt(mean_squared_error(y_train, xg_oof_train))))
print("ET-CV: {}".format(sqrt(mean_squared_error(y_train, et_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, rf_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, cb_oof_train))))
# Out:
# XG-CV: 0.2596954424083137
# ET-CV: 0.26296502347137407
# RF-CV: 0.2629856213006646
# RF-CV: 0.331012765614397

# %%
x_train = np.concatenate((xg_oof_train, et_oof_train, rf_oof_train, cb_oof_train), axis=1)
x_test = np.concatenate((xg_oof_test, et_oof_test, rf_oof_test, cb_oof_test), axis=1)

print("{},{}".format(x_train.shape, x_test.shape))
# Out:
# (307511, 4),(48744, 4)

# %%
logistic_regression = LogisticRegression()
logistic_regression.fit(x_train,y_train)

test['TARGET'] = logistic_regression.predict_proba(x_test)[:,1]

test[['SK_ID_CURR', 'TARGET']].to_csv('first_submission.csv', index=False, float_format='%.8f')
